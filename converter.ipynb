# %%
import vrplib
import numpy as np

# %%
instance = vrplib.read_instance("instances/solomon/raw/r108.txt", instance_format="solomon")

# %%
instance.keys()
# Out:
# dict_keys(['name', 'vehicles', 'capacity', 'node_coord', 'demand', 'time_window', 'service_time', 'edge_weight'])

# %%
type(instance.get("edge_weight"))
# Out:
# numpy.ndarray

# %%
coord_factor = 10
factor = 1000

# %%
type(instance["edge_weight"][0][0])
# Out:
# numpy.float64

# %%
instance["node_coord"] = coord_factor * instance["node_coord"]
instance["service_time"] = np.round(factor * instance["service_time"]).astype(int)
instance["edge_weight"] = np.round(factor * instance["edge_weight"]).astype(int)
instance["time_window"] = np.round(factor * instance["time_window"]).astype(int)

# %%
instance_loc = "instances/solomon/vrplib/r108.txt"
instance_data = {
    "NAME ": "R108",
    "COMMENT ": "SOLOMON",
    "TYPE ": "VRPTW",
    "DIMENSION ": 101,
    "EDGE_WEIGHT_TYPE ": "EXPLICIT",
    "VEHICLES ": instance.get("vehicles"),
    "EDGE_WEIGHT_FORMAT ": "FULL_MATRIX",
    "CAPACITY ": instance.get("capacity"),
    "EDGE_WEIGHT_SECTION": instance.get("edge_weight"),
    "NODE_COORD_SECTION": instance.get("node_coord"),
    "DEMAND_SECTION": instance.get("demand"),
    "DEPOT_SECTION": [1, -1],
    "SERVICE_TIME_SECTION": instance.get("service_time"),
    "TIME_WINDOW_SECTION": instance.get("time_window"),
}

# %%
vrplib.write_instance(instance_loc, instance_data)

# %%
ins_file = "instances/solomon/raw/r108.txt"

# %%
instance = vrplib.read_instance(ins_file, instance_format="solomon")

# %%
out = dict()
factor = 1000
c_factor = 10

# %%
out['name'] = instance['name']
out['type'] = 'solomon'
out['num_vehicle'] = instance['vehicles']
out['capacity'] = instance['capacity']

node_coords = [node.tolist() for node in instance['node_coord']]
node_coords = [[node[0] * c_factor, node[1] * c_factor] for node in node_coords]
demands = instance['demand'].tolist()
time_windows = [tw.tolist() for tw in instance['time_window']]
time_windows = [[tw[0] * factor, tw[1] * factor] for tw in time_windows]
service_times = instance['service_time'].tolist()
service_times = [st * factor for st in service_times]

# %%
customers = [{"id": i, "coord": node_coord, "demand": demand, "time_window": time_window, "service_time": service_time} for i, (node_coord, demand, time_window, service_time) in enumerate(zip(node_coords, demands, time_windows, service_times))]

# %%
customers
# Out:
# [{'id': 0,
#   'coord': [350, 350],
#   'demand': 0,
#   'time_window': [0, 230000],
#   'service_time': 0},
#  {'id': 1,
#   'coord': [410, 490],
#   'demand': 10,
#   'time_window': [0, 204000],
#   'service_time': 10000},
#  {'id': 2,
#   'coord': [350, 170],
#   'demand': 7,
#   'time_window': [0, 202000],
#   'service_time': 10000},
#  {'id': 3,
#   'coord': [550, 450],
#   'demand': 13,
#   'time_window': [0, 197000],
#   'service_time': 10000},
#  {'id': 4,
#   'coord': [550, 200],
#   'demand': 19,
#   'time_window': [139000, 169000],
#   'service_time': 10000},
#  {'id': 5,
#   'coord': [150, 300],
#   'demand': 26,
#   'time_window': [0, 199000],
#   'service_time': 10000},
#  {'id': 6,
#   'coord': [250, 300],
#   'demand': 3,
#   'time_window': [0, 208000],
#   'service_time': 10000},
#  {'id': 7,
#   'coord': [200, 500],
#   'demand': 5,
#   'time_window': [0, 198000],
#   'service_time': 10000},
#  {'id': 8,
#   'coord': [100, 430],
#   'demand': 9,
#   'time_window': [85000, 115000],
#   'service_time': 10000},
#  {'id': 9,
#   'coord': [550, 600],
#   'demand': 16,
#   'time_window': [87000, 117000],
#   'service_time': 10000},
#  {'id': 10,
#   'coord': [300, 600],
#   'demand': 16,
#   'time_window': [0, 194000],
#   'service_time': 10000},
#  {'id': 11,
#   'coord': [200, 650],
#   'demand': 12,
#   'time_window': [57000, 87000],
#   'service_time': 10000},
#  {'id': 12,
#   'coord': [500, 350],
#   'demand': 19,
#   'time_window': [0, 205000],
#   'service_time': 10000},
#  {'id': 13,
#   'coord': [300, 250],
#   'demand': 23,
#   'time_window': [149000, 179000],
#   'service_time': 10000},
#  {'id': 14,
#   'coord': [150, 100],
#   'demand': 20,
#   'time_window': [0, 187000],
#   'service_time': 10000},
#  {'id': 15,
#   'coord': [300, 50],
#   'demand': 8,
#   'time_window': [51000, 81000],
#   'service_time': 10000},
#  {'id': 16,
#   'coord': [100, 200],
#   'demand': 19,
#   'time_window': [0, 190000],
#   'service_time': 10000},
#  {'id': 17,
#   'coord': [50, 300],
#   'demand': 2,
#   'time_window': [0, 189000],
#   'service_time': 10000},
#  {'id': 18,
#   'coord': [200, 400],
#   'demand': 12,
#   'time_window': [0, 204000],
#   'service_time': 10000},
#  {'id': 19,
#   'coord': [150, 600],
#   'demand': 17,
#   'time_window': [0, 187000],
#   'service_time': 10000},
#  {'id': 20,
#   'coord': [450, 650],
#   'demand': 9,
#   'time_window': [0, 188000],
#   'service_time': 10000},
#  {'id': 21,
#   'coord': [450, 200],
#   'demand': 11,
#   'time_window': [0, 201000],
#   'service_time': 10000},
#  {'id': 22,
#   'coord': [450, 100],
#   'demand': 18,
#   'time_window': [0, 193000],
#   'service_time': 10000},
#  {'id': 23,
#   'coord': [550, 50],
#   'demand': 29,
#   'time_window': [58000, 88000],
#   'service_time': 10000},
#  {'id': 24,
#   'coord': [650, 350],
#   'demand': 3,
#   'time_window': [0, 190000],
#   'service_time': 10000},
#  {'id': 25,
#   'coord': [650, 200],
#   'demand': 6,
#   'time_window': [156000, 186000],
#   'service_time': 10000},
#  {'id': 26,
#   'coord': [450, 300],
#   'demand': 17,
#   'time_window': [0, 208000],
#   'service_time': 10000},
#  {'id': 27,
#   'coord': [350, 400],
#   'demand': 16,
#   'time_window': [0, 215000],
#   'service_time': 10000},
#  {'id': 28,
#   'coord': [410, 370],
#   'demand': 16,
#   'time_window': [0, 213000],
#   'service_time': 10000},
#  {'id': 29,
#   'coord': [640, 420],
#   'demand': 9,
#   'time_window': [0, 190000],
#   'service_time': 10000},
#  {'id': 30,
#   'coord': [400, 600],
#   'demand': 21,
#   'time_window': [0, 194000],
#   'service_time': 10000},
#  {'id': 31,
#   'coord': [310, 520],
#   'demand': 27,
#   'time_window': [0, 202000],
#   'service_time': 10000},
#  {'id': 32,
#   'coord': [350, 690],
#   'demand': 23,
#   'time_window': [0, 186000],
#   'service_time': 10000},
#  {'id': 33,
#   'coord': [530, 520],
#   'demand': 11,
#   'time_window': [0, 195000],
#   'service_time': 10000},
#  {'id': 34,
#   'coord': [650, 550],
#   'demand': 14,
#   'time_window': [0, 183000],
#   'service_time': 10000},
#  {'id': 35,
#   'coord': [630, 650],
#   'demand': 8,
#   'time_window': [0, 178000],
#   'service_time': 10000},
#  {'id': 36,
#   'coord': [20, 600],
#   'demand': 5,
#   'time_window': [0, 178000],
#   'service_time': 10000},
#  {'id': 37,
#   'coord': [200, 200],
#   'demand': 8,
#   'time_window': [0, 198000],
#   'service_time': 10000},
#  {'id': 38,
#   'coord': [50, 50],
#   'demand': 16,
#   'time_window': [73000, 103000],
#   'service_time': 10000},
#  {'id': 39,
#   'coord': [600, 120],
#   'demand': 31,
#   'time_window': [0, 186000],
#   'service_time': 10000},
#  {'id': 40,
#   'coord': [400, 250],
#   'demand': 9,
#   'time_window': [0, 208000],
#   'service_time': 10000},
#  {'id': 41,
#   'coord': [420, 70],
#   'demand': 5,
#   'time_window': [0, 191000],
#   'service_time': 10000},
#  {'id': 42,
#   'coord': [240, 120],
#   'demand': 5,
#   'time_window': [0, 194000],
#   'service_time': 10000},
#  {'id': 43,
#   'coord': [230, 30],
#   'demand': 7,
#   'time_window': [0, 185000],
#   'service_time': 10000},
#  {'id': 44,
#   'coord': [110, 140],
#   'demand': 18,
#   'time_window': [59000, 89000],
#   'service_time': 10000},
#  {'id': 45,
#   'coord': [60, 380],
#   'demand': 16,
#   'time_window': [0, 190000],
#   'service_time': 10000},
#  {'id': 46,
#   'coord': [20, 480],
#   'demand': 1,
#   'time_window': [0, 184000],
#   'service_time': 10000},
#  {'id': 47,
#   'coord': [80, 560],
#   'demand': 27,
#   'time_window': [0, 185000],
#   'service_time': 10000},
#  {'id': 48,
#   'coord': [130, 520],
#   'demand': 36,
#   'time_window': [0, 192000],
#   'service_time': 10000},
#  {'id': 49,
#   'coord': [60, 680],
#   'demand': 30,
#   'time_window': [0, 176000],
#   'service_time': 10000},
#  {'id': 50,
#   'coord': [470, 470],
#   'demand': 13,
#   'time_window': [0, 203000],
#   'service_time': 10000},
#  {'id': 51,
#   'coord': [490, 580],
#   'demand': 10,
#   'time_window': [0, 193000],
#   'service_time': 10000},
#  {'id': 52,
#   'coord': [270, 430],
#   'demand': 9,
#   'time_window': [0, 208000],
#   'service_time': 10000},
#  {'id': 53,
#   'coord': [370, 310],
#   'demand': 14,
#   'time_window': [85000, 115000],
#   'service_time': 10000},
#  {'id': 54,
#   'coord': [570, 290],
#   'demand': 18,
#   'time_window': [0, 197000],
#   'service_time': 10000},
#  {'id': 55,
#   'coord': [630, 230],
#   'demand': 2,
#   'time_window': [126000, 156000],
#   'service_time': 10000},
#  {'id': 56,
#   'coord': [530, 120],
#   'demand': 6,
#   'time_window': [0, 190000],
#   'service_time': 10000},
#  {'id': 57,
#   'coord': [320, 120],
#   'demand': 7,
#   'time_window': [0, 196000],
#   'service_time': 10000},
#  {'id': 58,
#   'coord': [360, 260],
#   'demand': 18,
#   'time_window': [180000, 210000],
#   'service_time': 10000},
#  {'id': 59,
#   'coord': [210, 240],
#   'demand': 28,
#   'time_window': [0, 202000],
#   'service_time': 10000},
#  {'id': 60,
#   'coord': [170, 340],
#   'demand': 3,
#   'time_window': [0, 201000],
#   'service_time': 10000},
#  {'id': 61,
#   'coord': [120, 240],
#   'demand': 13,
#   'time_window': [0, 194000],
#   'service_time': 10000},
#  {'id': 62,
#   'coord': [240, 580],
#   'demand': 19,
#   'time_window': [48000, 78000],
#   'service_time': 10000},
#  {'id': 63,
#   'coord': [270, 690],
#   'demand': 10,
#   'time_window': [0, 185000],
#   'service_time': 10000},
#  {'id': 64,
#   'coord': [150, 770],
#   'demand': 9,
#   'time_window': [0, 173000],
#   'service_time': 10000},
#  {'id': 65,
#   'coord': [620, 770],
#   'demand': 20,
#   'time_window': [0, 170000],
#   'service_time': 10000},
#  {'id': 66,
#   'coord': [490, 730],
#   'demand': 25,
#   'time_window': [0, 179000],
#   'service_time': 10000},
#  {'id': 67,
#   'coord': [670, 50],
#   'demand': 25,
#   'time_window': [73000, 103000],
#   'service_time': 10000},
#  {'id': 68,
#   'coord': [560, 390],
#   'demand': 36,
#   'time_window': [0, 198000],
#   'service_time': 10000},
#  {'id': 69,
#   'coord': [370, 470],
#   'demand': 6,
#   'time_window': [40000, 70000],
#   'service_time': 10000},
#  {'id': 70,
#   'coord': [370, 560],
#   'demand': 5,
#   'time_window': [0, 198000],
#   'service_time': 10000},
#  {'id': 71,
#   'coord': [570, 680],
#   'demand': 15,
#   'time_window': [0, 180000],
#   'service_time': 10000},
#  {'id': 72,
#   'coord': [470, 160],
#   'demand': 25,
#   'time_window': [0, 197000],
#   'service_time': 10000},
#  {'id': 73,
#   'coord': [440, 170],
#   'demand': 9,
#   'time_window': [0, 199000],
#   'service_time': 10000},
#  {'id': 74,
#   'coord': [460, 130],
#   'demand': 8,
#   'time_window': [139000, 169000],
#   'service_time': 10000},
#  {'id': 75,
#   'coord': [490, 110],
#   'demand': 18,
#   'time_window': [0, 192000],
#   'service_time': 10000},
#  {'id': 76,
#   'coord': [490, 420],
#   'demand': 13,
#   'time_window': [63000, 93000],
#   'service_time': 10000},
#  {'id': 77,
#   'coord': [530, 430],
#   'demand': 14,
#   'time_window': [169000, 199000],
#   'service_time': 10000},
#  {'id': 78,
#   'coord': [610, 520],
#   'demand': 3,
#   'time_window': [0, 188000],
#   'service_time': 10000},
#  {'id': 79,
#   'coord': [570, 480],
#   'demand': 23,
#   'time_window': [82000, 112000],
#   'service_time': 10000},
#  {'id': 80,
#   'coord': [560, 370],
#   'demand': 6,
#   'time_window': [0, 198000],
#   'service_time': 10000},
#  {'id': 81,
#   'coord': [550, 540],
#   'demand': 26,
#   'time_window': [0, 192000],
#   'service_time': 10000},
#  {'id': 82,
#   'coord': [150, 470],
#   'demand': 16,
#   'time_window': [0, 196000],
#   'service_time': 10000},
#  {'id': 83,
#   'coord': [140, 370],
#   'demand': 11,
#   'time_window': [0, 198000],
#   'service_time': 10000},
#  {'id': 84,
#   'coord': [110, 310],
#   'demand': 7,
#   'time_window': [91000, 121000],
#   'service_time': 10000},
#  {'id': 85,
#   'coord': [160, 220],
#   'demand': 41,
#   'time_window': [0, 196000],
#   'service_time': 10000},
#  {'id': 86,
#   'coord': [40, 180],
#   'demand': 35,
#   'time_window': [0, 184000],
#   'service_time': 10000},
#  {'id': 87,
#   'coord': [280, 180],
#   'demand': 26,
#   'time_window': [83000, 113000],
#   'service_time': 10000},
#  {'id': 88,
#   'coord': [260, 520],
#   'demand': 9,
#   'time_window': [0, 200000],
#   'service_time': 10000},
#  {'id': 89,
#   'coord': [260, 350],
#   'demand': 15,
#   'time_window': [0, 211000],
#   'service_time': 10000},
#  {'id': 90,
#   'coord': [310, 670],
#   'demand': 3,
#   'time_window': [0, 187000],
#   'service_time': 10000},
#  {'id': 91,
#   'coord': [150, 190],
#   'demand': 1,
#   'time_window': [0, 194000],
#   'service_time': 10000},
#  {'id': 92,
#   'coord': [220, 220],
#   'demand': 2,
#   'time_window': [18000, 48000],
#   'service_time': 10000},
#  {'id': 93,
#   'coord': [180, 240],
#   'demand': 22,
#   'time_window': [0, 199000],
#   'service_time': 10000},
#  {'id': 94,
#   'coord': [260, 270],
#   'demand': 27,
#   'time_window': [0, 207000],
#   'service_time': 10000},
#  {'id': 95,
#   'coord': [250, 240],
#   'demand': 20,
#   'time_window': [0, 205000],
#   'service_time': 10000},
#  {'id': 96,
#   'coord': [220, 270],
#   'demand': 11,
#   'time_window': [0, 204000],
#   'service_time': 10000},
#  {'id': 97,
#   'coord': [250, 210],
#   'demand': 12,
#   'time_window': [0, 202000],
#   'service_time': 10000},
#  {'id': 98,
#   'coord': [190, 210],
#   'demand': 10,
#   'time_window': [0, 198000],
#   'service_time': 10000},
#  {'id': 99,
#   'coord': [200, 260],
#   'demand': 9,
#   'time_window': [73000, 103000],
#   'service_time': 10000},
#  {'id': 100,
#   'coord': [180, 180],
#   'demand': 17,
#   'time_window': [165000, 195000],
#   'service_time': 10000}]

# %%
out['customers'] = customers

# %%
customers[1]
# Out:
# {'id': 1,
#  'coord': [410, 490],
#  'demand': 10,
#  'time_window': [0, 204000],
#  'service_time': 10000}

# %%
out['edge_weight'] = [l.tolist() for l in instance['edge_weight']]

# %%
out['edge_weight'] = [[round(num * factor) for num in row] for row in out['edge_weight']]

# %%
import json

out_json = json.dumps(out, indent=4)

# %%
with open("instances/solomon/r108.json", 'w') as outfile:
  outfile.write(out_json)
